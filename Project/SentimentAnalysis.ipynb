# %%
# Out:
#   File <tokenize>:32
#     <td> Important Step: Predictive Modeling</td>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# <body>
#  <a align="center" href="https://github.com/MurtadhaM/ML-5156">
#  <h1  align="center"><img src="https://upload.wikimedia.org/wikipedia/commons/9/91/Octicons-mark-github.svg" width="50"/> Data Mining Group Project</h1>
#
#
# ---
#
#    <h1 align="center">
# Github Repo
#
# </h1>
# </a>
# </body>
# <h1> <b> Sentiment Analysis on Twitter Data </b> </h1>
# <h4 align="center">
#                     Research topic: Sentiment Analysis on Twitter Data
# </h4>
# <h4 align="center">
#                     Reproduced by: Murtadha Marzouq
# </h4>
#
# <h4 align="center">
#                     Date: 05/10/2023
# </h4>
# <h4 align="center">
#                     Key Research to be Reproduced: Twitter sentiment analysis: Capturing sentiment from integrated resort tweets <a href="https://doi.org/10.1016/j.ijhm.2016.02.001">Link</a>
# <h4 align="center">
#                     Marzouq, Murtadha
# </h4>
#
#
#  <div width="100%"  border="1" >                    <tr>             <td>                <table border = "1"><tr><th>🎁 Task⭐</th>         <th>📬 Framework📬</th>                   </tr>                   <tr>                      <td>Step 1: Loading data</td>                      <td><a href="https://github.com/twintproject/twint">Pandas</a></td>                   </tr>                   <tr>                      <td>Step 2: Pre-processing the Data </td>                      <td><a href="https://spacy.io/usage/v3-2">SpaCy</a></td>
#  <tr>
#  <td> Step 3: Data analysis and visualization</td>
#   <td><a href="https://pandas.pydata.org/">Pandas</a></td>
#     <tr>
#    <td> Important Step: Predictive Modeling</td>
#   <td><a href="https://scikit-learn.org/stable/model_selection.html#model-selection/">pyldavis</a></td>
#          </tr>
#  </tr>
#  </tr>                </table>             </td>          </tr>                 </div>
# <h4 align="center"><b>Resources Used:</b></h4>
# <ol>
# <li>
# <p> https://github.com/twintproject/twint/wiki/Configuration </p>
# </li>
# <li>
# <p>https://medium.com/@pragya_paudyal/scraping-tweet-using-twint-and-analyzing-with-nlp-932e01ad5587</p>
# </li>
#
# <li>
# <p> https://health-tweets-topics.herokuapp.com/ </p>
# </li>
#
# <li>
# <p> https://pub.towardsai.net/tweet-topic-modeling-part-3-using-short-text-topic-modeling-on-tweets-bc969a827fef </p>
# </li>
#
# </ol>

# %%
# !pip3 install PyDrive
# !pip3 install gensim matplotlib nltk numpy pandas pyLDAvis scikit_learn spacy seaborn gensim   PyDrive
# !pip3 install gensim 
# !pip3 install pyldavis
# !git clone --depth=1 https://github.com/twintproject/twint.git
# !cd twint
# !pip3 install . -r requirements.txt
# !python3 -m spacy download en
# !pip3 install nltk
# Out:
# 1232.72s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# 1240.59s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached twint-2.1.20-py3-none-any.whl
# ...
#   Using cached aiohttp-3.8.4-cp311-cp311-macosx_10_9_x86_64.whl (355 kB)
# ...
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# ...
#   Using cached cchardet-2.1.7.tar.gz (653 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached elasticsearch-8.7.0-py3-none-any.whl (387 kB)
# ...
#   Using cached aiohttp_socks-0.8.0-py3-none-any.whl (9.4 kB)
# ...
#   Using cached schedule-1.2.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached geopy-2.3.0-py3-none-any.whl (119 kB)
# ...
#   Using cached googletransx-2.4.2-py3-none-any.whl
# ...
#   Using cached pycares-4.3.0-cp311-cp311-macosx_10_9_x86_64.whl (75 kB)
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#   Using cached yarl-1.8.2-cp311-cp311-macosx_10_9_x86_64.whl (59 kB)
# ...

# %% [markdown]
# # Step 1: Loading data

# %%
import gensim # Python library for topic modelling, document indexing and similarity retrieval.
from gensim import corpora
import pyLDAvis # This is used to help use interpret the topics in our model.
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
from datetime import timedelta
import datetime
import nest_asyncio # Package used to prevent a runtime error in Jupyter Notebooks.
import pandas as pd # Used to put data into dataframe.
import spacy
import re
import nltk # Text processing libraries for tokenization, parsing, classification, stemming, tagging and semantic reasoning.
import twint # Package used to collect Twitter data without a Twitter developer account.
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nest_asyncio.apply() 
# Downloading Filters and Dicts
nltk.download('wordnet') # So we are requesting to use this database. There are different models in the nltk models.
wnl = WordNetLemmatizer()
nlp = spacy.load('en_core_web_sm') # Likely point of issues when first running this program.
nltk.download('stopwords') # These are the maps to database collections we want.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /Users/dashm/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/dashm/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dashm/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# DISABLINNG ALL WARNINGS
import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# > Indented block
#
#
# # Step 1 Loading data
# ---
# :⛱
# **Successfully load the data you choose to analyze into memory**⛱
# <img align="center" width="50%" src="https://media.makeameme.org/created/go-ahead-load.jpg"/>

# %%
# FETCHING THE TWEETS
# Set the limit of tweets to be scraped
limit_of_tweets = 5
twint
def run_twint():

    #since_in_day = 5
    #This is used to start pulling Tweets from the most recent time.
    #since = (datetime.datetime.now() - timedelta(since_in_day)).strftime('%Y-%m-%d')
    c = twint.Config()
    #Keyword search for our def.
    c.Search = 'Police'
    #This is the number of Tweets we want to get in our search.
    c.Limit = limit_of_tweets
    #We want the search data to be saved into a CSV file.
    c.Store_csv = True
    #c.Since = since
    #Name of the file we save our data to.
    c.Output = 'output.csv'
    c.Pandas = True
    c.Pandas_clean = True
    #This is limiting the search to only English. 
    c.Lang = "en"
    twint.run.Search(c)
    df = twint.storage.panda.Tweets_df 
    return df


stop_words = set(stopwords.words('english'))
data = run_twint()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 29
#      25     return df
#      28 stop_words = set(stopwords.words('english'))
# ---> 29 data = run_twint()
#
# Cell In[25], line 9, in run_twint()
#       4 def run_twint():
#       5
#       6     #since_in_day = 5
#       7     #This is used to start pulling Tweets from the most recent time.
#       8     #since = (datetime.datetime.now() - timedelta(since_in_day)).strftime('%Y-%m-%d')
# ----> 9     c = twint.Config()
#      10     #Keyword search for our def.
#      11     c.Search = 'Police'
#
# AttributeError: module 'twint' has no attribute 'Config'
